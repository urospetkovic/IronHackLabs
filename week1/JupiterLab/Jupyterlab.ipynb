# %% [markdown]
# # Dream Holiday
# ### This notebook shows my holiday preference

# %%
def name():
    persName = input("Enter your name:")
    return persName

# %% [markdown]
# ![profilna.jpeg](attachment:profilna.jpeg)

# %%
def holiday():
    place = input('What is your favorite holiday destination?')
    return place

# %% [markdown]
# ![SOUTH-BEACHES.jpeg](attachment:SOUTH-BEACHES.jpeg)

# %% [markdown]
# <ul style="font-size:20px">
#     <li style="color:blue"> <b> swim </b> </li>
#     <li style="color:red"> <i> eat </i> </li>
#     <li style="color:green"> sleep </li>
# </ul>

# %% [markdown]
# https://www.youtube.com/watch?v=3zpoeidPeY4
