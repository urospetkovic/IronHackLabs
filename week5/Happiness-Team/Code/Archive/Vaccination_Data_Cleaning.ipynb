# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('/Users/jenniferdersjant/Desktop/vaccination-data.csv')

# %%
df.head()
# Out:
#           COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2021-06-22
# 1         Albania  ALB       EURO   REPORTING   2021-06-20
# 2         Algeria  DZA       AFRO   REPORTING   2021-06-24
# 3  American Samoa  ASM       WPRO   REPORTING   2021-06-21
# 4         Andorra  AND       EURO   REPORTING   2021-06-20
#
#    TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            765890.0                       582128.0
# 1            875580.0                       510783.0
# 2                 NaN                            NaN
# 3             44293.0                        24408.0
# 4             63272.0                        38665.0
#
#    TOTAL_VACCINATIONS_PER100  PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                      1.967                                 1.495
# 1                     30.400                                17.749
# 2                        NaN                                   NaN
# ...

# %%
df.columns = map(str.lower, df.columns)

# %%
df.head()
# Out:
#           country iso3 who_region data_source date_updated  \
# 0     Afghanistan  AFG       EMRO   REPORTING   2021-06-22
# 1         Albania  ALB       EURO   REPORTING   2021-06-20
# 2         Algeria  DZA       AFRO   REPORTING   2021-06-24
# 3  American Samoa  ASM       WPRO   REPORTING   2021-06-21
# 4         Andorra  AND       EURO   REPORTING   2021-06-20
#
#    total_vaccinations  persons_vaccinated_1plus_dose  \
# 0            765890.0                       582128.0
# 1            875580.0                       510783.0
# 2                 NaN                            NaN
# 3             44293.0                        24408.0
# 4             63272.0                        38665.0
#
#    total_vaccinations_per100  persons_vaccinated_1plus_dose_per100  \
# 0                      1.967                                 1.495
# 1                     30.400                                17.749
# 2                        NaN                                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               224 non-null    object
#  1   iso3                                  224 non-null    object
#  2   who_region                            224 non-null    object
#  3   data_source                           224 non-null    object
#  4   date_updated                          224 non-null    object
#  5   total_vaccinations                    223 non-null    float64
#  6   persons_vaccinated_1plus_dose         214 non-null    float64
#  7   total_vaccinations_per100             223 non-null    float64
#  8   persons_vaccinated_1plus_dose_per100  214 non-null    float64
#  9   vaccines_used                         220 non-null    object
#  10  first_vaccine_date                    199 non-null    object
# ...

# %%
df["first_vaccine_date"] = pd.to_datetime(df['first_vaccine_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               224 non-null    object
#  1   iso3                                  224 non-null    object
#  2   who_region                            224 non-null    object
#  3   data_source                           224 non-null    object
#  4   date_updated                          224 non-null    object
#  5   total_vaccinations                    223 non-null    float64
#  6   persons_vaccinated_1plus_dose         214 non-null    float64
#  7   total_vaccinations_per100             223 non-null    float64
#  8   persons_vaccinated_1plus_dose_per100  214 non-null    float64
#  9   vaccines_used                         220 non-null    object
# ...

# %%
df.tail()
# Out:
#                country iso3 who_region data_source date_updated  \
# 219           Viet Nam  VNM       WPRO   REPORTING   2021-06-18
# 220  Wallis and Futuna  WLF       WPRO   REPORTING   2021-05-21
# 221              Yemen  YEM       EMRO   REPORTING   2021-06-20
# 222             Zambia  ZMB       AFRO   REPORTING   2021-06-24
# 223           Zimbabwe  ZWE       AFRO   REPORTING   2021-06-24
#
#      total_vaccinations  persons_vaccinated_1plus_dose  \
# 219           2034781.0                      1944948.0
# 220              8186.0                         4341.0
# 221            251385.0                       251385.0
# 222            147220.0                       141934.0
# 223           1146378.0                       706158.0
#
#      total_vaccinations_per100  persons_vaccinated_1plus_dose_per100  \
# 219                      2.090                                 1.998
# 220                     72.790                                38.600
# ...

# %%
df.to_csv('/Users/jenniferdersjant/Desktop/vaccination-data-clean.csv', index = False)
