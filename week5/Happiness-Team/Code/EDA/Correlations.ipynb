# %%
import pandas as pd 
import numpy as numpy
import matplotlib as matplotlib
import seaborn as sns

# %%
df=pd.read_csv('/users/jenniferdersjant/Happiness-Team/data/happy_final.csv')

# %%
df.head(30)
# Out:
#         country  year  ladder_score  logged_gdp_per_capita  social_support  \
# 0   Afghanistan  2008         3.724                  7.370        0.451000
# 1   Afghanistan  2009         4.402                  7.540        0.552000
# 2   Afghanistan  2010         4.758                  7.647        0.539000
# 3   Afghanistan  2011         3.832                  7.620        0.521000
# 4   Afghanistan  2012         3.783                  7.705        0.521000
# 5   Afghanistan  2013         3.572                  7.725        0.484000
# 6   Afghanistan  2014         3.131                  7.718        0.526000
# 7   Afghanistan  2015         3.983                  7.702        0.529000
# 8   Afghanistan  2016         4.220                  7.697        0.559000
# 9   Afghanistan  2017         2.662                  7.697        0.491000
# 10  Afghanistan  2018         2.694                  7.692        0.508000
# ...

# %%
dfnum=df._get_numeric_data()
dfnum.head()
# Out:
#    year  ladder_score  logged_gdp_per_capita  social_support  \
# 0  2008         3.724                  7.370           0.451
# 1  2009         4.402                  7.540           0.552
# 2  2010         4.758                  7.647           0.539
# 3  2011         3.832                  7.620           0.521
# 4  2012         3.783                  7.705           0.521
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    50.80                         0.718       0.168
# 1                    51.20                         0.679       0.190
# 2                    51.60                         0.600       0.121
# 3                    51.92                         0.496       0.162
# 4                    52.24                         0.531       0.236
#
#    perceptions_of_corruption
# 0                      0.882
# 1                      0.850
# 2                      0.707
# 3                      0.731
# 4                      0.776

# %%
df_after_2012 = df.loc[df['year'] > 2012]

# %%
df_after_2012.head(10)
# Out:
#         country  year  ladder_score  logged_gdp_per_capita  social_support  \
# 5   Afghanistan  2013         3.572                  7.725           0.484
# 6   Afghanistan  2014         3.131                  7.718           0.526
# 7   Afghanistan  2015         3.983                  7.702           0.529
# 8   Afghanistan  2016         4.220                  7.697           0.559
# 9   Afghanistan  2017         2.662                  7.697           0.491
# 10  Afghanistan  2018         2.694                  7.692           0.508
# 11  Afghanistan  2019         2.375                  7.697           0.420
# 17      Albania  2013         4.551                  9.359           0.759
# 18      Albania  2014         4.814                  9.378           0.626
# 19      Albania  2015         4.607                  9.403           0.639
#
#     healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 5                     52.56                         0.578       0.061
# ...

# %%
dfnum.hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
sns.pairplot(dfnum)

# %%
dfnum_2012=df_after_2012._get_numeric_data()
dfnum_2012.head()
# Out:
#    year  ladder_score  logged_gdp_per_capita  social_support  \
# 5  2013         3.572                  7.725           0.484
# 6  2014         3.131                  7.718           0.526
# 7  2015         3.983                  7.702           0.529
# 8  2016         4.220                  7.697           0.559
# 9  2017         2.662                  7.697           0.491
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 5                    52.56                         0.578       0.061
# 6                    52.88                         0.509       0.104
# 7                    53.20                         0.389       0.080
# 8                    53.00                         0.523       0.042
# 9                    52.80                         0.427      -0.121
#
#    perceptions_of_corruption
# 5                      0.823
# 6                      0.871
# 7                      0.881
# 8                      0.793
# 9                      0.954

# %%
dfnum_2012.hist(bins=15, figsize=(15, 6), layout=(2, 4));

# %%
sns.pairplot(dfnum_2012)

# %%
corr_data = dfnum_2012.drop(['year'], axis=1)
correlations_matrix = corr_data.corr()
correlations_matrix
# Out:
#                               ladder_score  logged_gdp_per_capita  \
# ladder_score                      1.000000               0.782016
# logged_gdp_per_capita             0.782016               1.000000
# social_support                    0.729814               0.723286
# healthy_life_expectancy           0.769341               0.839548
# freedom_to_make_life_choices      0.542667               0.355494
# generosity                        0.118434              -0.053510
# perceptions_of_corruption        -0.406599              -0.322022
#
#                               social_support  healthy_life_expectancy  \
# ladder_score                        0.729814                 0.769341
# logged_gdp_per_capita               0.723286                 0.839548
# social_support                      1.000000                 0.679570
# healthy_life_expectancy             0.679570                 1.000000
# freedom_to_make_life_choices        0.413903                 0.391246
# ...

# %%
sns.heatmap(correlations_matrix, annot=True)

# %%
sns.regplot(x='healthy_life_expectancy', y='logged_gdp_per_capita', data=dfnum_2012)

# %%
sns.regplot(x='social_support', y='logged_gdp_per_capita', data=dfnum_2012)

# %%
sns.regplot(x='healthy_life_expectancy', y='social_support', data=dfnum_2012)

# %%
sns.regplot(x='ladder_score', y='logged_gdp_per_capita', data=dfnum_2012)

# %%
sns.regplot(x='ladder_score', y='social_support', data=dfnum_2012)

# %%
sns.regplot(x='ladder_score', y='healthy_life_expectancy', data=dfnum_2012)

# %%
sns.regplot(x='ladder_score', y='logged_gdp_per_capita', data=dfnum_2012)

# %%
sns.regplot(x='ladder_score', y='social_support', data=dfnum_2012)

# %%
sns.boxplot(data=corr_data)

# %%
for column in corr_data:
    plt.figure()
    corr_data.boxplot([column])

# %%
fig = plt.figure(figsize=(6,3),dpi=150)
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0.2, hspace=0.4)
ax0 = fig.add_subplot(gs[0, 0])

background_color = "#fafafa"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) 

ax0.text(1.167,0.85,"2021 World Happiness Index",color='#323232',fontsize=28, fontweight='bold', fontfamily='sanserif',ha='center')
ax0.text(1.13,-0.35,"stand-out facts",color='lightgray',fontsize=28, fontweight='bold', fontfamily='monospace',ha='center')

ax0.text(0,0.4,"Finland",fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0,0.1,"Happiest",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(0.77,0.4,"9 of top 10",fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0.75,0.1,"in Europe",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(1.5,0.4,"7 of bottom 10",fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(1.5,0.1,"in Africa",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(2.25,0.4,"Afghanistan",fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(2.25,0.1,"Unhappiest",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.set_yticklabels('')
ax0.set_xticklabels('')
ax0.tick_params(axis='both',length=0)

for s in ['top','right','left','bottom']:
    ax0.spines[s].set_visible(False)
    

l1 = plt.Line2D([0.15, 1.95], [0.67, 0.67], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l1])
l2 = plt.Line2D([0.15, 1.95], [0.07, 0.07], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l2])
    
plt.show()
# Out:
# findfont: Font family ['sanserif'] not found. Falling back to DejaVu Sans.
