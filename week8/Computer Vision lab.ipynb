# %% [markdown]
# https://www.nature.com/articles/d41586-020-03187-3

# %% [markdown]
# ## Big brother IS watching. Laws and regulations differ from state to state, let's hope and do our best to use it for good causes, as information can be a strong weapon.

# %%
# %matplotlib inline
from IPython.display import Image
Image('tiger on wheels.png')

# %% [markdown]
# ## Tiger on wheels
# ## Looks more like orange underpants with metal decoration 😂
