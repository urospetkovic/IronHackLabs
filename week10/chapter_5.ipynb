# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult.data')

# %%
df.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 
            'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'wage_class']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education_num   32560 non-null  int64
#  5   marital_status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital_gain    32560 non-null  int64
#  11  capital_loss    32560 non-null  int64
#  12  hours_per_week  32560 non-null  int64
#  13  native_country  32560 non-null  object
#  14  wage_class      32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country wage_class
# ...

# %%
df['sex'][1]
# Out:
# ' Male'

# %%
df['sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: sex, dtype: int64

# %%
women = df.loc[df['sex'] == ' Female']

# %%
women['age'].mean()
# Out:
# 36.85823043357163

# %%
germans = df.loc[df['native_country'] == ' Germany']

# %%
germans.head()
# Out:
#       age     workclass  fnlwgt      education  education_num  \
# 121    30       Private   77143      Bachelors             13
# 279    22       Private   34918      Bachelors             13
# 766    22       Private  151790   Some-college             10
# 1008   26       Private  109186   Some-college             10
# 1141   59   Federal-gov  212448        HS-grad              9
#
#            marital_status        occupation    relationship    race      sex  \
# 121         Never-married   Exec-managerial       Own-child   Black     Male
# 279         Never-married    Prof-specialty   Not-in-family   White   Female
# 766    Married-civ-spouse             Sales            Wife   White   Female
# 1008   Married-civ-spouse             Sales         Husband   White     Male
# 1141              Widowed             Sales       Unmarried   White   Female
#
#       capital_gain  capital_loss  hours_per_week native_country wage_class
# ...

# %%
germans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137 entries, 121 to 32340
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             137 non-null    int64
#  1   workclass       137 non-null    object
#  2   fnlwgt          137 non-null    int64
#  3   education       137 non-null    object
#  4   education_num   137 non-null    int64
#  5   marital_status  137 non-null    object
#  6   occupation      137 non-null    object
#  7   relationship    137 non-null    object
#  8   race            137 non-null    object
#  9   sex             137 non-null    object
#  10  capital_gain    137 non-null    int64
#  11  capital_loss    137 non-null    int64
#  12  hours_per_week  137 non-null    int64
#  13  native_country  137 non-null    object
#  14  wage_class      137 non-null    object
# dtypes: int64(6), object(9)
# memory usage: 21.2+ KB

# %%
more_than_50k = df.loc[df['wage_class'] == ' >50K']

# %%
more_than_50k.head()
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
#
#          marital_status        occupation    relationship  \
# 6    Married-civ-spouse   Exec-managerial         Husband
# 7         Never-married    Prof-specialty   Not-in-family
# 8    Married-civ-spouse   Exec-managerial         Husband
# 9    Married-civ-spouse   Exec-managerial         Husband
# 10   Married-civ-spouse    Prof-specialty         Husband
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 6                 White     Male             0             0              45
# ...

# %%
more_than_50k['age'].mean()
# Out:
# 44.24984058155847

# %%
more_than_50k['age'].std()
# Out:
# 10.51902771985177

# %%
less_than_50k = df.loc[df['wage_class'] == ' <=50K']

# %%
less_than_50k.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital_status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country wage_class
# ...

# %%
less_than_50k['age'].mean()
# Out:
# 36.78364820583357

# %%
less_than_50k['age'].std()
# Out:
# 14.020365001830326

# %%
more_than_50k['education'].unique()
# Out:
# array([' HS-grad', ' Masters', ' Bachelors', ' Some-college',
#        ' Assoc-voc', ' Doctorate', ' Prof-school', ' Assoc-acdm',
#        ' 7th-8th', ' 12th', ' 10th', ' 11th', ' 9th', ' 5th-6th',
#        ' 1st-4th'], dtype=object)

# %%
more_than_50k.head()
# Out:
#     age          workclass  fnlwgt      education  education_num  \
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
#
#          marital_status        occupation    relationship  \
# 6    Married-civ-spouse   Exec-managerial         Husband
# 7         Never-married    Prof-specialty   Not-in-family
# 8    Married-civ-spouse   Exec-managerial         Husband
# 9    Married-civ-spouse   Exec-managerial         Husband
# 10   Married-civ-spouse    Prof-specialty         Husband
#
#                    race      sex  capital_gain  capital_loss  hours_per_week  \
# 6                 White     Male             0             0              45
# ...

# %%
indian = df.loc[df['race'] == ' Amer-Indian-Eskimo']

# %%
indian['age'].max()
# Out:
# 82

# %%
more_than_50k['marital_status'].str.contains('Married').value_counts()
# Out:
# True     6736
# False    1105
# Name: marital_status, dtype: int64

# %%
df['hours_per_week'].max()
# Out:
# 99

# %%
df.loc[df['hours_per_week'] == 99]
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 934     37            Private  176900        HS-grad              9
# 1171    25            Private  404616        Masters             14
# 1886    55   Self-emp-not-inc  184425   Some-college             10
# 3577    37       Self-emp-inc  382802      Doctorate             16
# 4085    50                  ?  174964           10th              6
# ...    ...                ...     ...            ...            ...
# 30991   40       Self-emp-inc  104235        Masters             14
# 31680   43            Private  266324        HS-grad              9
# 31698   43   Self-emp-not-inc  163108   Some-college             10
# 32468   58       Self-emp-inc  181974      Doctorate             16
# 32530   30                  ?   33811      Bachelors             13
#
#             marital_status        occupation    relationship  \
# 934     Married-civ-spouse      Craft-repair         Husband
# ...

# %%
japan = df.loc[df['native_country'] == ' Japan']

# %%
japan_poor = japan.loc[japan['wage_class'] == ' <=50K']

# %%
japan_poor['hours_per_week'].mean()
# Out:
# 41.0

# %%
japan_rich = japan.loc[japan['wage_class'] == ' >50K']

# %%
japan_rich['hours_per_week'].mean()
# Out:
# 47.958333333333336
